# %% [markdown]
# # COVID 19 Dashboard

# %%
# hide
# default_exp plot
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt
from covid19.core import *

# %%
init(None)

# %% [markdown]
# Get data for all countries

# %%
confirmed, deaths = get_countries()
confirmed
# Out:
#                                       Lat       Long_  2020-01-22  2020-01-23  \
# Country_Region
#  Azerbaijan                      0.000000    0.000000         0.0         0.0
# Afghanistan                     33.939110   67.709953         0.0         0.0
# Albania                         41.153300   20.168300         0.0         0.0
# Algeria                         28.033900    1.659600         0.0         0.0
# Andorra                         42.506300    1.521800         0.0         0.0
# ...                                   ...         ...         ...         ...
# Vietnam                         28.116648  216.554398         0.0         2.0
# West Bank and Gaza              31.952200   35.233200         0.0         0.0
# Zambia                         -13.133897   27.849332         0.0         0.0
# Zimbabwe                       -19.015438   29.154857         0.0         0.0
# occupied Palestinian territory   0.000000    0.000000         0.0         0.0
#
# ...

# %% [markdown]
# Use the pandas [diff](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.diff.html) function to compute the difference between the date columns

# %%
diff = confirmed[get_date_column_names(confirmed)].diff(axis=1)
diff
# Out:
#                                 2020-01-22  2020-01-23  2020-01-24  \
# Country_Region
#  Azerbaijan                            NaN         0.0         0.0
# Afghanistan                            NaN         0.0         0.0
# Albania                                NaN         0.0         0.0
# Algeria                                NaN         0.0         0.0
# Andorra                                NaN         0.0         0.0
# ...                                    ...         ...         ...
# Vietnam                                NaN         2.0         0.0
# West Bank and Gaza                     NaN         0.0         0.0
# Zambia                                 NaN         0.0         0.0
# Zimbabwe                               NaN         0.0         0.0
# occupied Palestinian territory         NaN         0.0         0.0
#
#                                 2020-01-25  2020-01-26  2020-01-27  \
# Country_Region
# ...

# %% [markdown]
# These are the x labels for the bar chart

# %%
diff.loc["US"].keys()
# Out:
# Index(['2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25', '2020-01-26',
#        '2020-01-27', '2020-01-28', '2020-01-29', '2020-01-30', '2020-01-31',
#        '2020-02-01', '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05',
#        '2020-02-06', '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10',
#        '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14', '2020-02-15',
#        '2020-02-16', '2020-02-17', '2020-02-18', '2020-02-19', '2020-02-20',
#        '2020-02-21', '2020-02-22', '2020-02-23', '2020-02-24', '2020-02-25',
#        '2020-02-26', '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01',
#        '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06',
#        '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11',
#        '2020-03-12', '2020-03-13', '2020-03-14', '2020-03-15', '2020-03-16',
#        '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21',
# ...

# %% [markdown]
# These are the values for the bar chart

# %%
diff.loc["US"]
# Out:
# 2020-01-22        NaN
# 2020-01-23        0.0
# 2020-01-24        1.0
# 2020-01-25        0.0
# 2020-01-26        3.0
#                ...
# 2020-03-24    10094.0
# 2020-03-25    12084.0
# 2020-03-26    18102.0
# 2020-03-27    17861.0
# 2020-03-28    19854.0
# Name: US, Length: 67, dtype: float64

# %%
plt.bar(diff.loc["US"].keys(), diff.loc["US"])
# Out:
# <BarContainer object of 67 artists>

# %%
confirmed.loc["US"]
# Out:
# Lat           135695.736041
# Long_        -328596.540686
# 2020-01-22         1.000000
# 2020-01-23         1.000000
# 2020-01-24         2.000000
#                   ...
# 2020-03-24     53881.000000
# 2020-03-25     65965.000000
# 2020-03-26     84067.000000
# 2020-03-27    101928.000000
# 2020-03-28    121782.000000
# Name: US, Length: 69, dtype: float64

# %%
ax2 = plt.twinx()
ax2.plot(confirmed.loc["US"][2:].keys(), confirmed.loc["US"][2:])

# %%
import datetime
dates = [datetime.datetime.strptime(d, "%Y-%m-%d").date() for d in confirmed.loc["US"][2:].keys()]

# %%
country="US"
state=""
start_date="01-22-2020"
import datetime

dailyConfirmedCasesColor = (0.1, 0.1, 0.1, 0.3)
cumulativeConfirmedCasesColor = "#1f3a93ff"

if state == "":
    region = f"{country}"
else:
    region = f"{state}, {country}"
        
f = plt.figure()
ax1 = f.add_subplot()
plt.bar(dates, diff.loc["US"], color=dailyConfirmedCasesColor, width=0.5)
ax1.set_ylabel('Daily Confirmed Cases')

ax2 = plt.twinx()
ax2.plot(dates, confirmed.loc["US"][2:], color=cumulativeConfirmedCasesColor)
ax2.set_ylabel('Cumulative Confirmed Cases', color=cumulativeConfirmedCasesColor)
ax2.spines['right'].set_color(cumulativeConfirmedCasesColor)
ax2.set_yticklabels(ax2.get_yticks(), color=cumulativeConfirmedCasesColor)
ax2.legend(['Cumulative Confirmed Cases'])
ax2.grid(None)

ax1.set_title(f"{region} from {start_date}", loc="left", fontdict={'fontweight': 'bold'})
xticks = ax1.get_xticks()
ax1.set_xticklabels([datetime.datetime.fromordinal(int(tm)).strftime('%m-%d') for tm in xticks])
plt.show()

# %% [markdown]
# Write a function that will do a SxS plot of cumulative confirmed and deaths SxS

# %%
# export

import datetime
import matplotlib.pyplot as plt

dailyConfirmedCasesColor = (0.1, 0.1, 0.1, 0.3)
cumulativeConfirmedCasesColor = "#1f3a93ff"

def plot_cumulative_and_daily(cum, diff, title, figure, rows, columns, index):
    # Compute the dates for the x axis of the combined plot
    dates = [datetime.datetime.strptime(d, "%Y-%m-%d").date() for d in cum.keys()]

    # Plot the bar chart of daily cases first
    ax1 = f.add_subplot(rows, columns, index)
    plt.bar(dates, diff, color=dailyConfirmedCasesColor, width=0.5)
    ax1.set_ylabel("Daily")
    xticks = ax1.get_xticks()
    
    # Plot the cumulative confirmed cases line chart as an overlay to the bar chart
    ax2 = plt.twinx()
    ax2.plot(dates, cum, color=cumulativeConfirmedCasesColor)
    ax2.set_ylabel("Cumulative", color=cumulativeConfirmedCasesColor)
    ax2.spines["right"].set_color(cumulativeConfirmedCasesColor)
    ax2.set_yticklabels(ax2.get_yticks(), color=cumulativeConfirmedCasesColor)
    ax2.legend(["Cumulative"])
    ax2.grid(None)

    # Format the x tick labels and add a title to the chart
    labels = [datetime.datetime.fromordinal(int(tm)).strftime("%m-%d") for tm in xticks]
    ax1.set_xticklabels(labels)
    ax1.set_title(title)

# %%
f = plt.figure(figsize=(12, 6))
f.subplots_adjust(wspace=0.5)

plot_cumulative_and_daily(confirmed.loc["US"][2:], diff.loc["US"], "US Confirmed", f, 1, 2, 1)
diffd = deaths[get_date_column_names(deaths)].diff(axis=1)
plot_cumulative_and_daily(deaths.loc["US"][2:], diffd.loc["US"], "US Deaths", f, 1, 2, 2)

# %% [markdown]
# Next, let's plot all states

# %%
states = get_state_names("US")
states.sort()
states
# Out:
# array(['Alabama', 'Alaska', 'American Samoa', 'Arizona', 'Arkansas',
#        'California', 'Chicago', 'Colorado', 'Connecticut', 'D.C.',
#        'Delaware', 'Diamond Princess', 'District of Columbia', 'Florida',
#        'Georgia', 'Grand Princess', 'Grand Princess Cruise Ship', 'Guam',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota',
#        'Northern Mariana Islands', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Puerto Rico', 'Recovered', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'U.S.',
#        'US', 'Unassigned Location (From Diamond Princess)',
#        'United States Virgin Islands', 'Utah', 'Vermont',
# ...

# %%
diffc.loc["Washington"].iloc[0][3:]
# Out:
# 2020-01-25      0.0
# 2020-01-26      0.0
# 2020-01-27      0.0
# 2020-01-28      0.0
# 2020-01-29      0.0
#               ...
# 2020-03-24    107.0
# 2020-03-25    263.0
# 2020-03-26    616.0
# 2020-03-27    270.0
# 2020-03-28    553.0
# Name: US, Length: 64, dtype: float64

# %%
confirmed, deaths = get_country_states("US")

diffc = confirmed[get_date_column_names(confirmed)].diff(axis=1)
diffd = deaths[get_date_column_names(deaths)].diff(axis=1)

for state in states:
    f = plt.figure(figsize=(12,6))
    f.subplots_adjust(wspace=0.5)
    plot_cumulative_and_daily(confirmed.loc[state].iloc[0][3:], diffc.loc[state].iloc[0], f"{state} Confirmed", f, 1, 2, 1)
    plot_cumulative_and_daily(deaths.loc[state].iloc[0][3:], diffd.loc[state].iloc[0], f"{state} Deaths", f, 1, 2, 2)
    plt.show()

# %%
states = get_state_names("Canada")
states.sort()
states

confirmed, deaths = get_country_states("Canada")

diffc = confirmed[get_date_column_names(confirmed)].diff(axis=1)
diffd = deaths[get_date_column_names(deaths)].diff(axis=1)

for state in states:
    f = plt.figure(figsize=(12,6))
    f.subplots_adjust(wspace=0.5)
    plot_cumulative_and_daily(confirmed.loc[state].iloc[0][3:], diffc.loc[state].iloc[0], f"{state} Confirmed", f, 1, 2, 1)
    plot_cumulative_and_daily(deaths.loc[state].iloc[0][3:], diffd.loc[state].iloc[0], f"{state} Deaths", f, 1, 2, 2)
    plt.show()

# %%
regions = get_region_names("US", "Washington")
regions.sort()
regions
# Out:
# array(['Adams', 'Asotin', 'Benton', 'Chelan', 'Clallam', 'Clark',
#        'Columbia', 'Cowlitz', 'Douglas', 'Ferry', 'Franklin', 'Garfield',
#        'Garfield County', 'Grant', 'Grays Harbor', 'Island', 'Jefferson',
#        'King', 'Kitsap', 'Kittitas', 'Klickitat', 'Lewis', 'Lincoln',
#        'Mason', 'Okanogan', 'Pacific', 'Pend Oreille', 'Pierce',
#        'San Juan', 'Seattle', 'Skagit', 'Skamania', 'Snohomish',
#        'Spokane', 'Stevens', 'Thurston', 'Unassigned',
#        'Unassigned Location', 'Wahkiakum', 'Walla Walla',
#        'Walla Walla County', 'Washington', 'Whatcom', 'Whitman', 'Yakima'],
#       dtype=object)

# %%
confirmed, deaths = get_country_state_regions("US", "Washington")

# %%
confirmed.loc[confirmed["Admin2"]=="King"].sum()
# Out:
# Country_Region                    USUS
# Province_State    WashingtonWashington
# Admin2                        KingKing
# FIPS                             53033
# Lat                            47.4914
#                           ...
# 2020-03-24                        1170
# 2020-03-25                        1359
# 2020-03-26                        1577
# 2020-03-27                        1577
# 2020-03-28                        2077
# Length: 73, dtype: object
